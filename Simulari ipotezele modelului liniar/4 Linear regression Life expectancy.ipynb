# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
#functions
def get_nice_corr_matrix(data: pd.DataFrame):
    corr_matrix=data.corr()
    # mask = np.zeros_like(corr_matrix, dtype=np.bool) Worked for another numpy version
    # mask[np.triu_indices_from(mask)]= True

    # Create a mask with zeros
    mask = np.zeros_like(corr_matrix, dtype=bool)

    # Set upper triangle elements to True
    mask[np.triu_indices_from(mask)] = True

    f, ax = plt.subplots(figsize=(15, 15))


    heatmap = sns.heatmap(corr_matrix,
                        mask = mask,
                        square = True,
                        linewidths = .5,
                        cmap = 'coolwarm',
                        cbar_kws = {'shrink': .4,
                                    'ticks' : [-1, -.5, 0, 0.5, 1]},
                        vmin = -1,
                        vmax = 1,
                        annot = True,
                        fmt='.2f',
                        annot_kws = {'size': 15})

    #add the column names as labels
    ax.set_yticklabels(corr_matrix.columns, rotation = 0)
    ax.set_xticklabels(corr_matrix.columns)
    ax.set_title('Correlation matrix')

    sns.set_style({'xtick.bottom': True}, {'ytick.left': True})
    plt.show()

# %% [markdown]
# # Regresia multipla pentru estimarea sperantei de viata

# %%
df = pd.read_csv('../data/life_expectancy.csv')
df
# Out:
#                   Country Country Code                      Region  \
# 0                  Angola          AGO          Sub-Saharan Africa
# 1                 Albania          ALB       Europe & Central Asia
# 2    United Arab Emirates          ARE  Middle East & North Africa
# 3               Argentina          ARG   Latin America & Caribbean
# 4                 Armenia          ARM       Europe & Central Asia
# ..                    ...          ...                         ...
# 123            Uzbekistan          UZB       Europe & Central Asia
# 124               Vietnam          VNM         East Asia & Pacific
# 125          South Africa          ZAF          Sub-Saharan Africa
# 126                Zambia          ZMB          Sub-Saharan Africa
# 127              Zimbabwe          ZWE          Sub-Saharan Africa
#
#      Life expectancy  GDP per capita  Corruption  \
# 0             61.147     2809.626088    0.361111
# 1             78.573     5395.659532    0.416667
# 2             77.972    42701.443045    0.666667
# 3             76.667    10056.637940    0.409722
# 4             75.087     4604.646324    0.333333
# ..               ...             ...         ...
# 123           71.725     1784.009816         NaN
# 124           75.400     2715.275980    0.416667
# 125           64.131     6624.761865    0.493056
# 126           63.886     1305.001031    0.388889
# 127           61.490     1316.740657    0.166667
#
#      Mortality caused by road traffic injury  Health Expenditure %  \
# 0                                       26.1              2.533360
# 1                                       11.7                   NaN
# 2                                        8.9              4.275049
# 3                                       14.1              9.510071
# 4                                       20.0             11.335264
# ..                                       ...                   ...
# 123                                     11.7              5.617604
# 124                                     30.6              5.249656
# 125                                     22.2              9.109355
# 126                                     20.5              5.312203
# 127                                     41.2              7.703565
#
#      Education Expenditure %
# 0                   1.927457
# 1                   3.916650
# 2                   3.867370
# 3                   4.724170
# 4                   2.561850
# ..                       ...
# 123                 7.001860
# 124                 4.061970
# 125                 5.917710
# 126                 4.465180
# 127                      NaN
#
# [128 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Country                                  128 non-null    object
#  1   Country Code                             128 non-null    object
#  2   Region                                   128 non-null    object
#  3   Life expectancy                          128 non-null    float64
#  4   GDP per capita                           127 non-null    float64
#  5   Corruption                               113 non-null    float64
#  6   Mortality caused by road traffic injury  128 non-null    float64
#  7   Health Expenditure %                     126 non-null    float64
#  8   Education Expenditure %                  77 non-null     float64
# dtypes: float64(6), object(3)
# memory usage: 9.1+ KB

# %% [markdown]
# #### __Discutie__ despre causal graph

# %%
numeric_cols = [ 'Life expectancy',
       'GDP per capita', 'Corruption',
       'Mortality caused by road traffic injury', 'Health Expenditure %',
       'Education Expenditure %']

# %% [markdown]
# ## EDA
# * Missing values
# * Correlations
# * Type of variables
# * Distributions

# %% [markdown]
# ### Missing values

# %%
#missing values
df.isna().mean()
# Out:
# Country                                    0.000000
# Country Code                               0.000000
# Region                                     0.000000
# Life expectancy                            0.000000
# GDP per capita                             0.007812
# Corruption                                 0.117188
# Mortality caused by road traffic injury    0.000000
# Health Expenditure %                       0.015625
# Education Expenditure %                    0.398438
# dtype: float64

# %% [markdown]
# Pentru Education Expenditure avem foarte multe valori lipsa. Nu o sa folosim aceasta variabila.

# %% [markdown]
# ### __Discutie__ despre substituire valori lipsa (data imputation)
#
# Posibile solutii:

# %%
#for GDP per capita, Corruption and Health Exp we substiute NA with the average of the region

df[df['Corruption'].isna()]
# Out:
#                       Country Country Code                     Region  \
# 8                     Burundi          BDI         Sub-Saharan Africa
# 10                      Benin          BEN         Sub-Saharan Africa
# 15     Bosnia and Herzegovina          BIH      Europe & Central Asia
# 19                   Barbados          BRB  Latin America & Caribbean
# 21   Central African Republic          CAF         Sub-Saharan Africa
# 37                    Eritrea          ERI         Sub-Saharan Africa
# 45                    Georgia          GEO      Europe & Central Asia
# 65                   Cambodia          KHM        East Asia & Pacific
# 70                    Lesotho          LSO         Sub-Saharan Africa
# 82                 Mauritania          MRT         Sub-Saharan Africa
# 83                  Mauritius          MUS         Sub-Saharan Africa
# 92                      Nepal          NPL                 South Asia
# 113                      Chad          TCD         Sub-Saharan Africa
# 116                Tajikistan          TJK      Europe & Central Asia
# 123                Uzbekistan          UZB      Europe & Central Asia
#
#      Life expectancy  GDP per capita  Corruption  \
# 8          61.584000      228.213589         NaN
# 10         61.771000     1219.515506         NaN
# 15         77.401000     6119.762345         NaN
# 19         79.190000    18148.497845         NaN
# 21         53.283000      467.908032         NaN
# 37         66.321000             NaN         NaN
# 45         73.767000     4697.983652         NaN
# 65         69.823000     1643.121389         NaN
# 70         54.331000     1113.372140         NaN
# 82         64.925000     1743.302901         NaN
# 83         74.235854    11097.168977         NaN
# 92         70.778000     1194.956876         NaN
# 113        54.239000      709.540043         NaN
# 116        71.097000      890.544402         NaN
# 123        71.725000     1784.009816         NaN
#
#      Mortality caused by road traffic injury  Health Expenditure %  \
# 8                                       35.5              7.990914
# 10                                      26.8              2.388429
# 15                                      13.5              9.049099
# 19                                       8.2              6.299904
# 21                                      37.7              7.753009
# 37                                      37.9              4.458767
# 45                                      12.4              6.657443
# 65                                      19.6              6.989083
# 70                                      31.9             11.269464
# 82                                      25.6              3.303297
# 83                                      12.2              6.199437
# 92                                      16.3              4.445151
# 113                                     32.4              4.353631
# 116                                     15.7              7.105294
# 123                                     11.7              5.617604
#
#      Education Expenditure %
# 8                   5.346684
# 10                  2.965200
# 15                       NaN
# 19                  3.203990
# 21                  1.768712
# 37                       NaN
# 45                  3.808640
# 65                       NaN
# 70                  7.991712
# 82                  1.824370
# 83                  4.719300
# 92                  4.240000
# 113                 2.372460
# 116                 5.712900
# 123                 7.001860

# %%
for column in ['GDP per capita', 'Corruption','Health Expenditure %']:
    # Calculate the average of X1 for each region
    region_averages = df.groupby('Region')[column].mean()

    # Impute missing values in X1 with the average of the corresponding region
    df[column] = df.apply(lambda row: region_averages[row['Region']] if pd.isnull(row[column]) else row[column], axis=1)
    
    print(f"Variable {column} solved")
# Out:
# Variable GDP per capita solved
# Variable Corruption solved
# Variable Health Expenditure % solved

# %%
df.isna().mean()
# Out:
# Country                                    0.000000
# Country Code                               0.000000
# Region                                     0.000000
# Life expectancy                            0.000000
# GDP per capita                             0.000000
# Corruption                                 0.000000
# Mortality caused by road traffic injury    0.000000
# Health Expenditure %                       0.000000
# Education Expenditure %                    0.398438
# dtype: float64

# %% [markdown]
# ### Distributions

# %%
sns.pairplot(df[numeric_cols],plot_kws=dict(marker="+", linewidth=1),palette="Paired")
# Out:
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1513: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=vector, **plot_kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)
# c:\Users\octav\anaconda3\envs\econometrie-avansata\Lib\site-packages\seaborn\axisgrid.py:1615: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=x, y=y, **kwargs)

# %%
for column in numeric_cols:
    sns.set(rc={'figure.figsize':(11.7,8.27)})
    g = sns.boxplot(data=df,palette='Paired',x=column,y='Region')
    g.set_title (f"Distribution of {column} by region")
    #g.set(xlabel='Proportion of missing values for each country')
    plt.show()
# Out:
# C:\Users\octav\AppData\Local\Temp\ipykernel_20004\1464013260.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.boxplot(data=df,palette='Paired',x=column,y='Region')
# C:\Users\octav\AppData\Local\Temp\ipykernel_20004\1464013260.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.boxplot(data=df,palette='Paired',x=column,y='Region')
# C:\Users\octav\AppData\Local\Temp\ipykernel_20004\1464013260.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.boxplot(data=df,palette='Paired',x=column,y='Region')
# C:\Users\octav\AppData\Local\Temp\ipykernel_20004\1464013260.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.boxplot(data=df,palette='Paired',x=column,y='Region')
# C:\Users\octav\AppData\Local\Temp\ipykernel_20004\1464013260.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.boxplot(data=df,palette='Paired',x=column,y='Region')
# C:\Users\octav\AppData\Local\Temp\ipykernel_20004\1464013260.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.boxplot(data=df,palette='Paired',x=column,y='Region')

# %% [markdown]
# ### Corelatii

# %%
get_nice_corr_matrix(df[numeric_cols])

# %%
for x in numeric_cols:
    if x=='Life expectancy':
        continue
    sns.regplot(data=df, x=x,y='Life expectancy')
    plt.show()

# %% [markdown]
# ### __Discutie__ despre feature engineering
#
# __Discutie__ despre standardizare

# %%
df['ln_gdp'] = np.log(df['GDP per capita'])
sns.regplot(data=df, x='ln_gdp',y='Life expectancy')
plt.show()

# %% [markdown]
# Inlocuim GDP per capita cu log(GDP per capita), castigam performanta mai buna a modelului, dar pierdem putin din interpretabilitate

# %% [markdown]
# # Estimare model liniar

# %%
import statsmodels.api as sm

X_cols = ['ln_gdp','Corruption',
 'Mortality caused by road traffic injury',
 'Health Expenditure %']

y_col = ['Life expectancy']

# Add constant term to independent variables
X = sm.add_constant(df[X_cols])

# Fit the model
model1 = sm.OLS(df[y_col], X).fit()

# Print model summary
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life expectancy   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.766
# Method:                 Least Squares   F-statistic:                     105.1
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):           1.03e-38
# Time:                        17:55:38   Log-Likelihood:                -347.98
# No. Observations:                 128   AIC:                             706.0
# Df Residuals:                     123   BIC:                             720.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# const                                      44.1088      3.484     12.660      0.000      37.212      51.006
# ln_gdp                                      3.6505      0.386      9.464      0.000       2.887       4.414
# Corruption                                 -3.4852      2.778     -1.254      0.212      -8.985       2.014
# Mortality caused by road traffic injury    -0.1889      0.045     -4.192      0.000      -0.278      -0.100
# Health Expenditure %                        0.2746      0.152      1.810      0.073      -0.026       0.575
# ==============================================================================
# Omnibus:                       16.280   Durbin-Watson:                   2.136
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.424
# Skew:                          -0.682   Prob(JB):                     1.35e-05
# Kurtosis:                       4.531   Cond. No.                         233.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### __Discutie__ despre ce facem in continuare
#
# * Enumerat solutii
# * Interpretabilitate vs performanta

# %%
get_nice_corr_matrix(df[X_cols])

# %%
X_cols_v2 = ['ln_gdp',
 'Mortality caused by road traffic injury',
 'Health Expenditure %']

y_col = ['Life expectancy']

# Add constant term to independent variables
X = sm.add_constant(df[X_cols_v2])

# Fit the model
model2 = sm.OLS(df[y_col], X).fit()

# Print model summary
print(model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life expectancy   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.765
# Method:                 Least Squares   F-statistic:                     138.9
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):           1.74e-39
# Time:                        17:55:38   Log-Likelihood:                -348.79
# No. Observations:                 128   AIC:                             705.6
# Df Residuals:                     124   BIC:                             717.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# const                                      44.6757      3.463     12.902      0.000      37.822      51.529
# ln_gdp                                      3.4296      0.344      9.970      0.000       2.749       4.111
# Mortality caused by road traffic injury    -0.1795      0.045     -4.030      0.000      -0.268      -0.091
# Health Expenditure %                        0.2119      0.144      1.476      0.142      -0.072       0.496
# ==============================================================================
# Omnibus:                       14.859   Durbin-Watson:                   2.097
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.122
# Skew:                          -0.660   Prob(JB):                     7.04e-05
# Kurtosis:                       4.357   Cond. No.                         228.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm

X_cols_v3 = ['ln_gdp',
 'Mortality caused by road traffic injury']

y_col = ['Life expectancy']

# Add constant term to independent variables
X = sm.add_constant(df[X_cols_v3])

# Fit the model
model3 = sm.OLS(df[y_col], X).fit()

# Print model summary
print(model3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life expectancy   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     205.4
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):           3.15e-40
# Time:                        17:55:38   Log-Likelihood:                -349.91
# No. Observations:                 128   AIC:                             705.8
# Df Residuals:                     125   BIC:                             714.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# const                                      44.7209      3.479     12.855      0.000      37.836      51.606
# ln_gdp                                      3.5894      0.328     10.940      0.000       2.940       4.239
# Mortality caused by road traffic injury    -0.1816      0.045     -4.061      0.000      -0.270      -0.093
# ==============================================================================
# Omnibus:                       13.572   Durbin-Watson:                   2.097
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.625
# Skew:                          -0.633   Prob(JB):                     0.000245
# Kurtosis:                       4.231   Cond. No.                         220.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### __Discutie__ despre indicatorii din summary
#
# * R-squared - Cat din variatia lui y poate fi pusa pe seama variatiei lui X
# * F- statistic: Testeaza daca X, in aceasta forma, influenteaza Y. H0: toti beta sunt 0, H1: cel putin unul e semnificativ. P-value f f mic (0.05) => invatam ceva nou decat default action H0 => acceptam H1
# * Log likelihood: valoarea rezultata din MLE, nu ne ajuta prea mult acum, eventual la comparare
# * AIC / BIC: Information criteria, avand mai multe modele se poate compara care e mai bun
# * Omnibus: Similar cu testul F
# * Skew and Kurt: se refera la distributia erorilor
# * Durbin Watson: ne spune daca erorile sunt autocorelate. Daca e in jur de 2, nu sunt autocorelate (sau f f putin)
# * JB: Ne spune daca erorile sunt normal distribuite

# %% [markdown]
# Scrierea predictiilorsi erorilor

# %%
df['Life expectancy pred'] = model3.predict(X)
df['error'] = df['Life expectancy'] - df['Life expectancy pred']
sns.histplot(df['error'])
# Out:
# <Axes: xlabel='error', ylabel='Count'>

# %%
#set a baseline error
df['baseline pred'] = np.average(df['Life expectancy'])

# %%
#masuram cu cat s-a imbunatatit eroarea noului model vs baseline
from sklearn.metrics import mean_absolute_error

mape_baseline = mean_absolute_error(df['Life expectancy'], df['baseline pred'])
mape_model = mean_absolute_error(df['Life expectancy'], df['Life expectancy pred'])

print(f"Baseline MAPE: {mape_baseline}\nModel MAPE:{mape_model}")
# Out:
# Baseline MAPE: 6.2586470113614725
# Model MAPE:2.8005317801473963

# %% [markdown]
# __Discutie__ despre testare.
#
# In sample, out of sample, train, test, validation

# %% [markdown]
# ## Vizualizari model

# %%
df[['Life expectancy','ln_gdp','Mortality caused by road traffic injury']].head()
# Out:
#    Life expectancy     ln_gdp  Mortality caused by road traffic injury
# 0           61.147   7.940807                                     26.1
# 1           78.573   8.593350                                     11.7
# 2           77.972  10.661988                                      8.9
# 3           76.667   9.215988                                     14.1
# 4           75.087   8.434821                                     20.0

# %%
# # Create 3D plot
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')

# # Plot scatter plot
# ax.scatter(df['Mortality caused by road traffic injury'], df['ln_gdp'], df['Life expectancy'], color='blue', label='Points')

# # Plot plane
# x1_grid, x2_grid = np.meshgrid(np.linspace(min(df['Mortality caused by road traffic injury']),
#                                             max(df['Mortality caused by road traffic injury']), 10),
#                                               np.linspace(min(df['ln_gdp']), max(df['ln_gdp']), 10))
# z2_plane = - model3.params[1] * x1_grid + model3.params[2] * x2_grid + model3.params[0]
# ax.plot_surface(x1_grid, x2_grid, z2_plane, alpha=0.5, color='orange', label='Plane')


# # Set labels and legend
# ax.set_xlabel('Mortality caused by road traffic injury')
# ax.set_ylabel('ln_gdp')
# ax.set_zlabel('Life expectancy')
# ax.set_title('3D Scatter Plot with Plane')
# ax.legend()
# plt.show()

# %%
print(model3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life expectancy   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     205.4
# Date:                Mon, 08 Apr 2024   Prob (F-statistic):           3.15e-40
# Time:                        18:02:29   Log-Likelihood:                -349.91
# No. Observations:                 128   AIC:                             705.8
# Df Residuals:                     125   BIC:                             714.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# const                                      44.7209      3.479     12.855      0.000      37.836      51.606
# ln_gdp                                      3.5894      0.328     10.940      0.000       2.940       4.239
# Mortality caused by road traffic injury    -0.1816      0.045     -4.061      0.000      -0.270      -0.093
# ==============================================================================
# Omnibus:                       13.572   Durbin-Watson:                   2.097
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.625
# Skew:                          -0.633   Prob(JB):                     0.000245
# Kurtosis:                       4.231   Cond. No.                         220.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import plotly.graph_objects as go
import numpy as np

# Example data

x = df['ln_gdp']
y = df['Mortality caused by road traffic injury']
z = df['Life expectancy']

# Create trace for scatter plot
scatter_trace = go.Scatter3d(x=x, y=y, z=z, mode='markers', marker=dict(color='blue', size=5), name='Points')

# Plot plane
x_grid, y_grid = np.meshgrid(np.linspace(min(x), max(x), 5), np.linspace(min(y), max(y), 5))
z2_plane = model3.params[0] + model3.params[1] * x_grid - model3.params[2] * y_grid 
plane_trace = go.Surface(x=x_grid, y=y_grid, z=z2_plane, opacity=0.5, colorscale='Oranges', name='Plane')

# Create layout for the plot
layout = go.Layout(scene=dict(xaxis=dict(title='ln_gdp'),
                               yaxis=dict(title='Mortality caused by road traffic injury'),
                               zaxis=dict(title='Life expectancy')),
                   margin=dict(l=0, r=0, b=0, t=0))

# Create figure
fig = go.Figure(data=[scatter_trace, plane_trace], layout=layout)

# Display the plot
fig.show()
# Out:
# C:\Users\octav\AppData\Local\Temp\ipykernel_20004\218131196.py:15: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
z2_plane
# Out:
# array([[  36.55612011,   11.59018598,  -13.37574815,  -38.34168228,
#          -63.30761641,  -88.27355054, -113.23948467, -138.20541881,
#         -163.17135294, -188.13728707],
#        [  36.43089408,   11.46495995,  -13.50097418,  -38.46690831,
#          -63.43284244,  -88.39877657, -113.36471071, -138.33064484,
#         -163.29657897, -188.2625131 ],
#        [  36.30566805,   11.33973392,  -13.62620021,  -38.59213434,
#          -63.55806847,  -88.5240026 , -113.48993674, -138.45587087,
#         -163.421805  , -188.38773913],
#        [  36.18044202,   11.21450789,  -13.75142624,  -38.71736037,
#          -63.6832945 ,  -88.64922864, -113.61516277, -138.5810969 ,
#         -163.54703103, -188.51296516],
#        [  36.05521599,   11.08928186,  -13.87665227,  -38.8425864 ,
#          -63.80852054,  -88.77445467, -113.7403888 , -138.70632293,
#         -163.67225706, -188.63819119],
#        [  35.92998996,   10.96405583,  -14.0018783 ,  -38.96781244,
#          -63.93374657,  -88.8996807 , -113.86561483, -138.83154896,
#         -163.79748309, -188.76341722],
#        [  35.80476393,   10.8388298 ,  -14.12710433,  -39.09303847,
#          -64.0589726 ,  -89.02490673, -113.99084086, -138.95677499,
#         -163.92270912, -188.88864325],
#        [  35.6795379 ,   10.71360377,  -14.25233037,  -39.2182645 ,
#          -64.18419863,  -89.15013276, -114.11606689, -139.08200102,
#         -164.04793515, -189.01386928],
#        [  35.55431187,   10.58837773,  -14.3775564 ,  -39.34349053,
#          -64.30942466,  -89.27535879, -114.24129292, -139.20722705,
#         -164.17316118, -189.13909531],
#        [  35.42908584,   10.4631517 ,  -14.50278243,  -39.46871656,
#          -64.43465069,  -89.40058482, -114.36651895, -139.33245308,
#         -164.29838721, -189.26432134]])
